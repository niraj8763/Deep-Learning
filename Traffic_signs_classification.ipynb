# %% [markdown]
# <a href="https://colab.research.google.com/github/niraj8763/Deep-Learning/blob/master/Traffic_signs_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Import Libraries**

# %%
import keras
from keras.models import Sequential
from keras.layers.convolutional import Conv2D ,MaxPooling2D
from keras.layers import Dense, Dropout, Flatten
from keras.optimizers import Adam
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
import pickle
import pandas as pd
import numpy as np
import random

# %% [markdown]
# ### **Import Dataset and Explore it**

# %%
# cloning repo containing the traffic sign dataset
# !git clone https://bitbucket.org/jadslim/german-traffic-signs
# Out:
# Cloning into 'german-traffic-signs'...
# remote: Counting objects: 6, done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 6 (delta 0), reused 0 (delta 0)
# Unpacking objects: 100% (6/6), done.

# %%
# list dataset contents
 
# !ls german-traffic-signs
# Out:
# signnames.csv  test.p  train.p	valid.p

# %%
#load the dataset

data = pd.read_csv('german-traffic-signs/signnames.csv')

# %%
data
# Out:
#     ClassId                                           SignName
# 0         0                               Speed limit (20km/h)
# 1         1                               Speed limit (30km/h)
# 2         2                               Speed limit (50km/h)
# 3         3                               Speed limit (60km/h)
# 4         4                               Speed limit (70km/h)
# 5         5                               Speed limit (80km/h)
# 6         6                        End of speed limit (80km/h)
# 7         7                              Speed limit (100km/h)
# 8         8                              Speed limit (120km/h)
# 9         9                                         No passing
# 10       10       No passing for vechiles over 3.5 metric tons
# 11       11              Right-of-way at the next intersection
# 12       12                                      Priority road
# 13       13                                              Yield
# 14       14                                               Stop
# 15       15                                        No vechiles
# 16       16           Vechiles over 3.5 metric tons prohibited
# 17       17                                           No entry
# 18       18                                    General caution
# 19       19                        Dangerous curve to the left
# 20       20                       Dangerous curve to the right
# 21       21                                       Double curve
# 22       22                                         Bumpy road
# 23       23                                      Slippery road
# 24       24                          Road narrows on the right
# 25       25                                          Road work
# 26       26                                    Traffic signals
# 27       27                                        Pedestrians
# 28       28                                  Children crossing
# 29       29                                  Bicycles crossing
# 30       30                                 Beware of ice/snow
# 31       31                              Wild animals crossing
# 32       32                End of all speed and passing limits
# 33       33                                   Turn right ahead
# 34       34                                    Turn left ahead
# 35       35                                         Ahead only
# 36       36                               Go straight or right
# 37       37                                Go straight or left
# 38       38                                         Keep right
# 39       39                                          Keep left
# 40       40                               Roundabout mandatory
# 41       41                                  End of no passing
# 42       42  End of no passing by vechiles over 3.5 metric ...

# %%
#loading pickled dataset

with open("german-traffic-signs/train.p",mode='rb') as training:
  train = pickle.load(training)

with open("german-traffic-signs/valid.p",mode='rb') as validation:
  valid = pickle.load(validation)

with open("german-traffic-signs/test.p",mode='rb') as testing:
  test = pickle.load(testing)

# %%
X_train , y_train = train['features'], train['labels']
X_validation , y_validation = valid['features'], valid['labels']
X_test , y_test = test['features'], test['labels']

# %%
print(X_train.shape)
print(X_validation.shape)
print(X_test.shape)
# Out:
# (34799, 32, 32, 3)
# (4410, 32, 32, 3)
# (12630, 32, 32, 3)

# %%
index = np.random.randint(1,len(X_train))
plt.imshow(X_train[index])
print("image label={}".format(y_train[index]))
# Out:
# image label=25

# %% [markdown]
# # Image Pre-processing

# %% [markdown]
# ### 1. Converting to grayscale
# ### 2. Histogram Equalization
# ### 3. Normalization

# %%
# shuffle the data
from sklearn.utils import shuffle
X_train , y_train = shuffle(X_train,y_train)

# %%
def preprocessing(img): 
  #convert to grayscale
  img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
  #Applying histogram equalization 
  img = cv2.equalizeHist(img)
  #Normalization
  img = img/255
  return img

# %%
X_train_processed = np.array(list(map(preprocessing,X_train)))
X_validation_processed = np.array(list(map(preprocessing,X_validation)))
X_test_processed = np.array(list(map(preprocessing,X_test)))

# %%
X_train_processed = X_train_processed.reshape(34799,32,32,1)
X_test_processed = X_test_processed.reshape(12630,32,32,1)
X_validation_processed = X_validation_processed.reshape(4410,32,32,1)

# %%
print(X_train_processed.shape)
print(X_test_processed.shape)
print(X_validation_processed.shape)
# Out:
# (34799, 32, 32, 1)
# (12630, 32, 32, 1)
# (4410, 32, 32, 1)

# %%
i= random.randint(1,len(X_train))
plt.imshow(X_train_processed[i].squeeze(),cmap='gray')
plt.figure()
plt.imshow(X_train[i].squeeze())

# %% [markdown]
# # Build Deep Convolution Neural Network Model

# %%
model = Sequential()
# add the convolutional layer
# filters, size of filters,input_shape,activation_function
model.add(Conv2D(32,(5,5),activation='relu',input_shape=(32,32,1)))

# pooling layer
model.add(MaxPooling2D(pool_size=(2,2)))

# place a dropout layer
model.add(Dropout(0.25))

# add another convolutional layer
model.add(Conv2D(64,(5,5),activation='relu'))

# pooling layer
model.add(MaxPooling2D(pool_size=(2,2)))

# Flatten the image to 1 dimensional array
model.add(Flatten())

# add a dense layer : amount of nodes, activation
model.add(Dense(256,activation='relu'))

# place a dropout layer
# 0.5 drop out rate is recommended, half input nodes will be dropped at each update
model.add(Dropout(0.5))

# defining the ouput layer of our network
model.add(Dense(43,activation='softmax'))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 28, 28, 32)        832
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 14, 14, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 10, 10, 64)        51264
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1600)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               409856
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 43)                11051
# =================================================================
# Total params: 473,003
# Trainable params: 473,003
# Non-trainable params: 0
# _________________________________________________________________

# %%
#compile our model
model.compile(Adam(lr=0.0001),loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
history = model.fit(X_train_processed,
                    y_train,
                    batch_size=500,
                    epochs=50,
                    verbose=1,
                    validation_data=(X_validation_processed,y_validation))
# Out:
# Train on 34799 samples, validate on 4410 samples
# Epoch 1/50
# 34799/34799 [==============================] - 8s 242us/step - loss: 3.5590 - accuracy: 0.0619 - val_loss: 3.4815 - val_accuracy: 0.1739
# Epoch 2/50
# 34799/34799 [==============================] - 2s 61us/step - loss: 3.2840 - accuracy: 0.1548 - val_loss: 3.0652 - val_accuracy: 0.3125
# Epoch 3/50
# 34799/34799 [==============================] - 2s 60us/step - loss: 2.7216 - accuracy: 0.3196 - val_loss: 2.4035 - val_accuracy: 0.4363
# Epoch 4/50
# 34799/34799 [==============================] - 2s 61us/step - loss: 2.2032 - accuracy: 0.4244 - val_loss: 1.9415 - val_accuracy: 0.4921
# Epoch 5/50
# 34799/34799 [==============================] - 2s 62us/step - loss: 1.8788 - accuracy: 0.4825 - val_loss: 1.6339 - val_accuracy: 0.5621
# Epoch 6/50
# 34799/34799 [==============================] - 2s 61us/step - loss: 1.6304 - accuracy: 0.5402 - val_loss: 1.3724 - val_accuracy: 0.6458
# Epoch 7/50
# 34799/34799 [==============================] - 2s 61us/step - loss: 1.4484 - accuracy: 0.5826 - val_loss: 1.2282 - val_accuracy: 0.6707
# Epoch 8/50
# 34799/34799 [==============================] - 2s 62us/step - loss: 1.2944 - accuracy: 0.6204 - val_loss: 1.0666 - val_accuracy: 0.7231
# Epoch 9/50
# 34799/34799 [==============================] - 2s 62us/step - loss: 1.1641 - accuracy: 0.6570 - val_loss: 0.9574 - val_accuracy: 0.7506
# Epoch 10/50
# 34799/34799 [==============================] - 2s 62us/step - loss: 1.0721 - accuracy: 0.6844 - val_loss: 0.8601 - val_accuracy: 0.7707
# Epoch 11/50
# 34799/34799 [==============================] - 2s 61us/step - loss: 0.9806 - accuracy: 0.7103 - val_loss: 0.7927 - val_accuracy: 0.7907
# Epoch 12/50
# 34799/34799 [==============================] - 2s 61us/step - loss: 0.9069 - accuracy: 0.7295 - val_loss: 0.7409 - val_accuracy: 0.8014
# Epoch 13/50
# 34799/34799 [==============================] - 2s 61us/step - loss: 0.8394 - accuracy: 0.7489 - val_loss: 0.6814 - val_accuracy: 0.8159
# Epoch 14/50
# 34799/34799 [==============================] - 2s 61us/step - loss: 0.7840 - accuracy: 0.7662 - val_loss: 0.6320 - val_accuracy: 0.8290
# Epoch 15/50
# 34799/34799 [==============================] - 2s 61us/step - loss: 0.7306 - accuracy: 0.7821 - val_loss: 0.5919 - val_accuracy: 0.8383
# Epoch 16/50
# 34799/34799 [==============================] - 2s 61us/step - loss: 0.6877 - accuracy: 0.7955 - val_loss: 0.5577 - val_accuracy: 0.8454
# Epoch 17/50
# 34799/34799 [==============================] - 2s 61us/step - loss: 0.6427 - accuracy: 0.8085 - val_loss: 0.5288 - val_accuracy: 0.8442
# Epoch 18/50
# 34799/34799 [==============================] - 2s 61us/step - loss: 0.6083 - accuracy: 0.8201 - val_loss: 0.4965 - val_accuracy: 0.8608
# Epoch 19/50
# 34799/34799 [==============================] - 2s 60us/step - loss: 0.5762 - accuracy: 0.8304 - val_loss: 0.4788 - val_accuracy: 0.8624
# Epoch 20/50
# 34799/34799 [==============================] - 2s 61us/step - loss: 0.5446 - accuracy: 0.8379 - val_loss: 0.4521 - val_accuracy: 0.8701
# Epoch 21/50
# 34799/34799 [==============================] - 2s 61us/step - loss: 0.5161 - accuracy: 0.8463 - val_loss: 0.4337 - val_accuracy: 0.8757
# Epoch 22/50
# 34799/34799 [==============================] - 2s 61us/step - loss: 0.4890 - accuracy: 0.8536 - val_loss: 0.4179 - val_accuracy: 0.8791
# Epoch 23/50
# 34799/34799 [==============================] - 2s 61us/step - loss: 0.4679 - accuracy: 0.8623 - val_loss: 0.4008 - val_accuracy: 0.8873
# Epoch 24/50
# 34799/34799 [==============================] - 2s 61us/step - loss: 0.4460 - accuracy: 0.8672 - val_loss: 0.3892 - val_accuracy: 0.8896
# Epoch 25/50
# 34799/34799 [==============================] - 2s 61us/step - loss: 0.4226 - accuracy: 0.8736 - val_loss: 0.3739 - val_accuracy: 0.8971
# Epoch 26/50
# 34799/34799 [==============================] - 2s 61us/step - loss: 0.4054 - accuracy: 0.8798 - val_loss: 0.3543 - val_accuracy: 0.8984
# Epoch 27/50
# 34799/34799 [==============================] - 2s 60us/step - loss: 0.3930 - accuracy: 0.8851 - val_loss: 0.3475 - val_accuracy: 0.8998
# Epoch 28/50
# 34799/34799 [==============================] - 2s 61us/step - loss: 0.3732 - accuracy: 0.8918 - val_loss: 0.3296 - val_accuracy: 0.9082
# Epoch 29/50
# 34799/34799 [==============================] - 2s 61us/step - loss: 0.3566 - accuracy: 0.8936 - val_loss: 0.3266 - val_accuracy: 0.9066
# Epoch 30/50
# 34799/34799 [==============================] - 2s 61us/step - loss: 0.3411 - accuracy: 0.8996 - val_loss: 0.3179 - val_accuracy: 0.9059
# Epoch 31/50
# 34799/34799 [==============================] - 2s 61us/step - loss: 0.3304 - accuracy: 0.9017 - val_loss: 0.3169 - val_accuracy: 0.9091
# Epoch 32/50
# 34799/34799 [==============================] - 2s 61us/step - loss: 0.3132 - accuracy: 0.9071 - val_loss: 0.3075 - val_accuracy: 0.9098
# Epoch 33/50
# 34799/34799 [==============================] - 2s 61us/step - loss: 0.3087 - accuracy: 0.9087 - val_loss: 0.2923 - val_accuracy: 0.9156
# Epoch 34/50
# 34799/34799 [==============================] - 2s 61us/step - loss: 0.2965 - accuracy: 0.9136 - val_loss: 0.2871 - val_accuracy: 0.9163
# Epoch 35/50
# 34799/34799 [==============================] - 2s 61us/step - loss: 0.2812 - accuracy: 0.9178 - val_loss: 0.2853 - val_accuracy: 0.9141
# Epoch 36/50
# 34799/34799 [==============================] - 2s 60us/step - loss: 0.2704 - accuracy: 0.9218 - val_loss: 0.2838 - val_accuracy: 0.9150
# Epoch 37/50
# 34799/34799 [==============================] - 2s 61us/step - loss: 0.2657 - accuracy: 0.9225 - val_loss: 0.2784 - val_accuracy: 0.9161
# Epoch 38/50
# 34799/34799 [==============================] - 2s 61us/step - loss: 0.2563 - accuracy: 0.9241 - val_loss: 0.2647 - val_accuracy: 0.9220
# Epoch 39/50
# 34799/34799 [==============================] - 2s 62us/step - loss: 0.2483 - accuracy: 0.9270 - val_loss: 0.2625 - val_accuracy: 0.9186
# Epoch 40/50
# 34799/34799 [==============================] - 2s 61us/step - loss: 0.2438 - accuracy: 0.9285 - val_loss: 0.2600 - val_accuracy: 0.9252
# Epoch 41/50
# 34799/34799 [==============================] - 2s 61us/step - loss: 0.2333 - accuracy: 0.9324 - val_loss: 0.2549 - val_accuracy: 0.9263
# Epoch 42/50
# 34799/34799 [==============================] - 2s 61us/step - loss: 0.2241 - accuracy: 0.9353 - val_loss: 0.2535 - val_accuracy: 0.9249
# Epoch 43/50
# 34799/34799 [==============================] - 2s 61us/step - loss: 0.2213 - accuracy: 0.9350 - val_loss: 0.2481 - val_accuracy: 0.9240
# Epoch 44/50
# 34799/34799 [==============================] - 2s 61us/step - loss: 0.2100 - accuracy: 0.9376 - val_loss: 0.2494 - val_accuracy: 0.9240
# Epoch 45/50
# 34799/34799 [==============================] - 2s 61us/step - loss: 0.2045 - accuracy: 0.9388 - val_loss: 0.2410 - val_accuracy: 0.9252
# Epoch 46/50
# 34799/34799 [==============================] - 2s 61us/step - loss: 0.1984 - accuracy: 0.9431 - val_loss: 0.2301 - val_accuracy: 0.9345
# Epoch 47/50
# 34799/34799 [==============================] - 2s 61us/step - loss: 0.1923 - accuracy: 0.9447 - val_loss: 0.2302 - val_accuracy: 0.9320
# Epoch 48/50
# 34799/34799 [==============================] - 2s 61us/step - loss: 0.1898 - accuracy: 0.9446 - val_loss: 0.2393 - val_accuracy: 0.9281
# Epoch 49/50
# 34799/34799 [==============================] - 2s 61us/step - loss: 0.1830 - accuracy: 0.9476 - val_loss: 0.2294 - val_accuracy: 0.9327
# Epoch 50/50
# 34799/34799 [==============================] - 2s 62us/step - loss: 0.1778 - accuracy: 0.9470 - val_loss: 0.2269 - val_accuracy: 0.9283

# %% [markdown]
# # Evaluate Performance of the model

# %%
score = model.evaluate(X_test_processed,y_test)
print('Test accuracy',score[1])
# Out:
# 12630/12630 [==============================] - 1s 110us/step
# Test accuracy 0.9167062640190125

# %%
history.history.keys()
# Out:
# dict_keys(['val_loss', 'val_accuracy', 'loss', 'accuracy'])

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['training','validation'])
plt.title('Training and validation losses')
plt.xlabel('epochs')
# Out:
# Text(0.5, 0, 'epochs')

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.legend(['training','validation'])
plt.title('Training and validation accuracy')
plt.xlabel('epochs')
# Out:
# Text(0.5, 0, 'epochs')

# %%
prediction = model.predict_classes(X_test_processed)
y_true_label= y_test

# %%
from sklearn.metrics import confusion_matrix
matrix = confusion_matrix(y_true_label,prediction)
plt.figure(figsize=(20,20))
sns.heatmap(matrix,annot=True)

# %%
L=6
W=6
fig , axes = plt.subplots(L,W,figsize=(12,12))
axes = axes.ravel()
for i in range(0,L*W):
  axes[i].imshow(X_test[i])
  axes[i].set_title('Prediction ={}\n True={}'.format(prediction[i],y_true_label[i]))
  axes[i].axis('off')
plt.subplots_adjust(wspace=1)

# %%
model.save('my_model.h5')
